# %%
import sys
import os

project_root = os.path.abspath("..")
sys.path.append(project_root)

# %%
"""
Full Multi-Agent Research System

This module integrates all components of the research system:
- User clarification and scoping
- Research brief generation  
- Multi-agent research coordination
- Final report generation

The system orchestrates the complete research workflow from initial user
input through final report delivery.
"""

from langchain_core.messages import HumanMessage
from langgraph.graph import StateGraph, START, END
# from langchain_anthropic import ChatAnthropic
from langchain_google_genai import ChatGoogleGenerativeAI

from deep_research.utils import get_today_str
from deep_research.prompt import final_report_generation_prompt
from deep_research.state import AgentState, AgentInputState
from deep_research.agents.scoping_agent import clarify_with_user, write_research_brief
from deep_research.agents.supervisor_agent import supervisor_agent

# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
# writer_model = ChatAnthropic(
#     model="claude-haiku-4-5-20251001",
#     temperature=0.7,
#     max_tokens=32000)
writer_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7,
    max_tokens=32000)

# %%
async def final_report_generation(state: AgentState):
    """
    Final report generation node.
    
    Synthesizes all research findings into a comprehensive final report
    """
    
    notes = state.get("notes", [])
    
    findings = "\n".join(notes)

    final_report_prompt = final_report_generation_prompt.format(
        research_brief=state.get("research_brief", ""),
        findings=findings,
        date=get_today_str()
    )
    
    final_report = await writer_model.ainvoke([HumanMessage(content=final_report_prompt)])
    
    return {
        "final_report": final_report.content, 
        "messages": ["Here is the final report: " + final_report.content],
    }

# %%
deep_researcher_builder = StateGraph(AgentState, input_schema=AgentInputState)

# Add workflow nodes
deep_researcher_builder.add_node("clarify_with_user", clarify_with_user)
deep_researcher_builder.add_node("write_research_brief", write_research_brief)
deep_researcher_builder.add_node("supervisor_subgraph", supervisor_agent)
deep_researcher_builder.add_node("final_report_generation", final_report_generation)

# Add workflow edges
deep_researcher_builder.add_edge(START, "clarify_with_user")
deep_researcher_builder.add_edge("write_research_brief", "supervisor_subgraph")
deep_researcher_builder.add_edge("supervisor_subgraph", "final_report_generation")
deep_researcher_builder.add_edge("final_report_generation", END)

# Compile the full workflow
agent = deep_researcher_builder.compile()

# %%
from utils import format_messages
from IPython.display import Image, display
from langgraph.checkpoint.memory import InMemorySaver

checkpointer = InMemorySaver()
full_agent = deep_researcher_builder.compile(checkpointer=checkpointer)
display(Image(full_agent.get_graph(xray=True).draw_mermaid_png()))

# %%
import inspect
from deep_research.agents.scoping_agent import get_today_str

print(inspect.getsource(get_today_str))
# Out:
# def get_today_str() -> str:
#     """Get current date in a human-readable format."""
#     return datetime.now().strftime("%a %b %d, %Y")

# %%
from langchain_core.messages import HumanMessage
thread = {"configurable": {"thread_id": "1", "recursion_limit": 50}}
result = await full_agent.ainvoke({"messages": [HumanMessage(content="Best IPL team")]}, config=thread)
format_messages(result['messages'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 from langchain_core.messages import HumanMessage
#       2 thread = {"configurable": {"thread_id": "1", "recursion_limit": 50}}
# ----> 3 result = await full_agent.ainvoke({"messages": [HumanMessage(content="Best IPL team")]}, config=thread)
#       4 format_messages(result['messages'])
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langgraph\pregel\main.py:4105, in Pregel.ainvoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    4102             chunks.append(chunk)
#    4103 else:
#    4104     # v1: collect interrupts from updates stream
# -> 4105     async for chunk in self.astream(
#    4106         input,
#    4107         config,
#    4108         context=context,
#    4109         stream_mode=(
#    4110             ["updates", "values"] if stream_mode == "values" else stream_mode
#    4111         ),
#    4112         print_mode=print_mode,
#    4113         output_keys=output_keys,
#    4114         interrupt_before=interrupt_before,
#    4115         interrupt_after=interrupt_after,
#    4116         durability=durability,
#    4117         control=control,
#    4118         **kwargs,
#    4119     ):
#    4120         if stream_mode == "values":
#    4121             if len(chunk) == 2:
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langgraph\pregel\main.py:3455, in Pregel.astream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    3453 for task in await loop.amatch_cached_writes():
#    3454     loop.output_writes(task.id, task.writes, cached=True)
# -> 3455 async for _ in runner.atick(
#    3456     [t for t in loop.tasks.values() if not t.writes],
#    3457     timeout=self.step_timeout,
#    3458     get_waiter=get_waiter,
#    3459     schedule_task=loop.aaccept_push,
#    3460 ):
#    3461     # emit output
#    3462     for o in _output(
#    3463         stream_mode,
#    3464         print_mode,
#    (...)   3470         _state_mapper,
#    3471     ):
#    3472         yield o
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langgraph\pregel\_runner.py:396, in PregelRunner.atick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     394 scheduled_error_handler = False
#     395 try:
# --> 396     await arun_with_retry(
#     397         t,
#     398         retry_policy,
#     399         stream=self.use_astream,
#     400         configurable={
#     401             CONFIG_KEY_CALL: partial(
#     402                 _acall,
#     403                 weakref.ref(t),
#     404                 stream=self.use_astream,
#     405                 retry_policy=retry_policy,
#     406                 futures=weakref.ref(futures),
#     407                 schedule_task=schedule_task,
#     408                 submit=self.submit,
#     409                 loop=loop,
#     410             ),
#     411         },
#     412     )
#     413     self.commit(t, None)
#     414 except Exception as exc:
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langgraph\pregel\_retry.py:744, in arun_with_retry(task, retry_policy, stream, match_cached_writes, configurable)
#     742             pass
#     743         break
# --> 744     return await task.proc.ainvoke(task.input, config)
#     745 result = await _arun_with_timeout(
#     746     task, config, resolved_timeout, attempt_ctx, stream=stream
#     747 )
#     748 _finish_timed_attempt(config, attempt_ctx)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:733, in RunnableSeq.ainvoke(self, input, config, **kwargs)
#     731     # run in context
#     732     with set_config_context(config, run) as context:
# --> 733         input = await asyncio.create_task(
#     734             step.ainvoke(input, config, **kwargs), context=context
#     735         )
#     736 else:
#     737     input = await step.ainvoke(input, config, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:279, in Task.__step(***failed resolving arguments***)
#     277         result = coro.send(None)
#     278     else:
# --> 279         result = coro.throw(exc)
#     280 except StopIteration as exc:
#     281     if self._must_cancel:
#     282         # Task is cancelled right before coro stops.
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:501, in RunnableCallable.ainvoke(self, input, config, **kwargs)
#     499         await run_manager.on_chain_end(ret)
#     500 else:
# --> 501     ret = await self.afunc(*args, **kwargs)
#     502 if self.recurse and isinstance(ret, Runnable):
#     503     return await ret.ainvoke(input, config)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\runnables\config.py:707, in run_in_executor(executor_or_config, func, *args, **kwargs)
#     703         raise RuntimeError from exc
#     705 if executor_or_config is None or isinstance(executor_or_config, dict):
#     706     # Use default executor with context copied from current context
# --> 707     return await asyncio.get_running_loop().run_in_executor(
#     708         None,
#     709         cast("Callable[..., T]", partial(copy_context().run, wrapper)),
#     710     )
#     712 return await asyncio.get_running_loop().run_in_executor(executor_or_config, wrapper)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\runnables\config.py:698, in run_in_executor.<locals>.wrapper()
#     696 def wrapper() -> T:
#     697     try:
# --> 698         return func(*args, **kwargs)
#     699     except StopIteration as exc:
#     700         # StopIteration can't be set on an asyncio.Future
#     701         # it raises a TypeError and leaves the Future pending forever
#     702         # so we need to convert it to a RuntimeError
#     703         raise RuntimeError from exc
#
# File d:\AI Projects\Deep_Research_Agent\deep_research\agents\scoping_agent.py:54, in clarify_with_user(state, config)
#      51 model = init_chat_model(model_name, temperature=0.7)
#      52 structured_output_model = model.with_structured_output(ClarifyWithUser)
# ---> 54 response = structured_output_model.invoke([
#      55     HumanMessage(content=clarify_with_user_instructions.format(
#      56         messages=get_buffer_string(messages=state["messages"]),
#      57         date=get_today_str()
#      58     ))
#      59 ])
#      61 if response.need_clarification:
#      62     return Command(
#      63         goto=END,
#      64         update={"messages": [AIMessage(content=response.question)]}
#      65     )
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:3442, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3440 with set_config_context(config) as context:
#    3441     if i == 0:
# -> 3442         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3443     else:
#    3444         input_ = context.run(step.invoke, input_, config)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\runnables\base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1766, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1764 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1765 try:
# -> 1766     data = self._create(payload)
#    1767 except anthropic.BadRequestError as e:
#    1768     _handle_anthropic_bad_request(e)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:1431, in ChatAnthropic._create(self, payload)
#    1429 if "betas" in payload:
#    1430     return self._client.beta.messages.create(**payload)
# -> 1431 return self._client.messages.create(**payload)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1009, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1002 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1003     warnings.warn(
#    1004         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1005         UserWarning,
#    1006         stacklevel=3,
#    1007     )
# -> 1009 return self._post(
#    1010     "/v1/messages",
#    1011     body=maybe_transform(
#    1012         {
#    1013             "max_tokens": max_tokens,
#    1014             "messages": messages,
#    1015             "model": model,
#    1016             "cache_control": cache_control,
#    1017             "container": container,
#    1018             "inference_geo": inference_geo,
#    1019             "metadata": metadata,
#    1020             "output_config": output_config,
#    1021             "service_tier": service_tier,
#    1022             "stop_sequences": stop_sequences,
#    1023             "stream": stream,
#    1024             "system": system,
#    1025             "temperature": temperature,
#    1026             "thinking": thinking,
#    1027             "tool_choice": tool_choice,
#    1028             "tools": tools,
#    1029             "top_k": top_k,
#    1030             "top_p": top_p,
#    1031         },
#    1032         message_create_params.MessageCreateParamsStreaming
#    1033         if stream
#    1034         else message_create_params.MessageCreateParamsNonStreaming,
#    1035     ),
#    1036     options=make_request_options(
#    1037         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1038     ),
#    1039     cast_to=Message,
#    1040     stream=stream or False,
#    1041     stream_cls=Stream[RawMessageStreamEvent],
#    1042 )
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\_base_client.py:1535, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1526     warnings.warn(
#    1527         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1528         "Please pass raw bytes via the `content` parameter instead.",
#    1529         DeprecationWarning,
#    1530         stacklevel=2,
#    1531     )
#    1532 opts = FinalRequestOptions.construct(
#    1533     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1534 )
# -> 1535 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\_base_client.py:1136, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1134 try:
#    1135     if chain is None:
# -> 1136         response, prepared = self._attempt_request(
#    1137             model_copy(input_options), stream=stream, retries_taken=retries_taken
#    1138         )
#    1139         if response.is_success:
#    1140             return self._process_response(
#    1141                 cast_to=cast_to,
#    1142                 options=prepared,
#    (...)   1146                 retries_taken=retries_taken,
#    1147             )
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\_base_client.py:1281, in SyncAPIClient._attempt_request(self, options, stream, retries_taken)
#    1271 """Prepare, build and send a single HTTP attempt.
#    1272
#    1273 Returns the response regardless of its status code, along with the prepared
#    (...)   1277 `APIConnectionError`).
#    1278 """
#    1279 options = self._prepare_options(options)
# -> 1281 request = self._build_request(options, retries_taken=retries_taken)
#    1282 self._prepare_request(request)
#    1284 kwargs: HttpxSendArgs = {}
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\_base_client.py:538, in BaseClient._build_request(self, options, retries_taken)
#     535     else:
#     536         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 538 headers = self._build_headers(options, retries_taken=retries_taken)
#     539 params = _merge_mappings(self.default_query, options.params)
#     540 content_type = headers.get("Content-Type")
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\_base_client.py:468, in BaseClient._build_headers(self, options, retries_taken)
#     458 custom_headers = options.headers or {}
#     459 headers_dict = _merge_mappings(
#     460     {
#     461         "x-stainless-timeout": str(options.timeout.read)
#    (...)    466     custom_headers,
#     467 )
# --> 468 self._validate_headers(headers_dict, custom_headers)
#     470 # headers are case-insensitive while dictionaries are not.
#     471 headers = httpx.Headers(headers_dict)
#
# File d:\AI Projects\Deep_Research_Agent\.venv\Lib\site-packages\anthropic\_client.py:388, in Anthropic._validate_headers(self, headers, custom_headers)
#     385 if headers.get("Authorization") or isinstance(custom_headers.get("Authorization"), Omit):
#     386     return
# --> 388 raise TypeError(
#     389     '"Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     390 )
#
# TypeError: "Could not resolve authentication method. Expected one of api_key, auth_token, or credentials to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"
# During task with name 'clarify_with_user' and id '5af3faf4-2a19-27c5-5b7c-b550c96c0df5'
